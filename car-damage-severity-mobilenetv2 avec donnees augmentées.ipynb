# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Entrainement du modèle de base avec la création de données augmentées
#
# </div>

# %%
# %%time
# Installations

# pip install tensorflow
# pip install Pillow
# pip install matplotlib
# pip install scikit-learn
# pip install seaborn
# pip install pydot

import time
start_time = time.time()

RecreerRepertoiresImages = False

# Bibliothèques principales
import numpy as np
from pathlib import Path
import os
from PIL import Image
import shutil
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import json

# TensorFlow et Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import clone_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")


# Reproductibilité
tf.random.set_seed(55)
np.random.seed(55)    
SEED = 55

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")


IMG_SIZE = (224, 224)
BATCH_SIZE = 32
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# ⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.21.0
#   - Keras      : 3.14.0
#   - NumPy      : 2.4.4
# CPU times: total: 6.45 s
# Wall time: 17.4 s

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Gestion du Dataset<br><br>
#
# L'option est prise de sauvegarder physiquement les données augmentées dans un répertoire pour pouvoir les consulter.
# Il apparait que certaines transformations parasitent un peu l'image.<br>
#
# La préparation est classique avec normalisation à 224 pixels en couleurs et le rapport de 80% entre la partie entrainement et la partie test.
#
# </div>

# %% [markdown]
# ---------------------------------------------------------
# # Dataset
# ---------------------------------------------------------

# %%
# %%time
# dataset

project_root = Path.cwd()
print("project_root : " + str(project_root))

data_dir_train = str(project_root) + "/CarDamageSeverityDatasetComplet_train"
data_dir_train = Path(data_dir_train)
print("data_dir_train:", data_dir_train)

data_dir_val = str(project_root) + "/data3a/validation"
data_dir_val = Path(data_dir_val)
print("data_dir_val:", data_dir_val)

IMG_SIZE = (224, 224)
# Out:
# project_root : c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning_V3
# data_dir_train: c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning_V3\CarDamageSeverityDatasetComplet_train
# data_dir_val: c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning_V3\data3a\validation
# CPU times: total: 0 ns
# Wall time: 1.47 ms

# %%
# %%time
# Analyse Dataset 

def analyse_dataset(p_chemin):

    # Explorer la structure
    print("\n📂 Structure du dataset : ", p_chemin)
    all_items = sorted([item.name for item in p_chemin.glob('*') if item.is_dir()])
    print(f"  - Tous les dossiers trouvés : {all_items}")

    class_names = all_items
    class_names = sorted(class_names)

    print(f"  - Nombre de classes : {len(class_names)}")

    if len(class_names) != 4:
        print("\n⚠️  Attention : Nombre de classes incorrect !")
        print("   Vérification du contenu du dataset...")

    # Compter les images par classe
    print("\n📊 Distribution des images par classe :")
    class_counts = {}
    total_images = 0
    for class_name in class_names:
        class_path = p_chemin / class_name
        count = len(list(class_path.glob('*.*')))
        class_counts[class_name] = count
        total_images += count
        print(f"  - {class_name:15s} : {count:4d} images")

    print(f"\n  - Total : {total_images} images")
    print(f"  - Moyenne par classe : {total_images / len(class_names):.0f} images")

    return class_names

class_names = analyse_dataset(data_dir_train)

class_names = analyse_dataset(data_dir_val)
# Out:
# 📂 Structure du dataset :  c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning_V3\CarDamageSeverityDatasetComplet_train
#   - Tous les dossiers trouvés : ['00-normal', '01-minor', '02-moderate', '03-severe']
#   - Nombre de classes : 4
#
# 📊 Distribution des images par classe :
#   - 00-normal       : 3258 images
#   - 01-minor        : 2712 images
#   - 02-moderate     : 2778 images
#   - 03-severe       : 2808 images
#
#   - Total : 11556 images
#   - Moyenne par classe : 2889 images
#
# 📂 Structure du dataset :  c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning_V3\data3a\validation
#   - Tous les dossiers trouvés : ['00-normal', '01-minor', '02-moderate', '03-severe']
#   - Nombre de classes : 4
#
# 📊 Distribution des images par classe :
#   - 00-normal       :  163 images
#   - 01-minor        :   82 images
#   - 02-moderate     :   75 images
#   - 03-severe       :   91 images
#
#   - Total : 411 images
#   - Moyenne par classe : 103 images
# CPU times: total: 250 ms
# Wall time: 337 ms

# %%
# %%time
#Préparation des datasets

# Créer le dataset d'entraînement avec filtrage des classes
train_ds = image_dataset_from_directory(
    data_dir_train,
    seed=SEED,
    image_size=IMG_SIZE,       # redimensionne toutes les images automatiquement
    batch_size=BATCH_SIZE,     # nombre d’images envoyées au modèle à chaque itération
    label_mode='categorical',  # One-hot encoding pour multi-classe
    class_names=class_names
)

# for images, labels in train_ds:
#     print(images.shape, "   ", labels.shape)  # (32, 224, 224, 3)         (32, nb_classes)
    
# Créer le dataset de validation avec les mêmes classes
val_ds = image_dataset_from_directory(
    data_dir_val,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Même ordre de classes
)

print(f"\n  - Train batches  : {len(train_ds)}")
print(f"  - Val batches    : {len(val_ds)}")
print(f"  - Batch size     : {BATCH_SIZE}")
print(f"  - Image size     : {IMG_SIZE}")
print(f"\n  - Train samples  : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Val samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# Found 11556 files belonging to 4 classes.
# Found 411 files belonging to 4 classes.
#
#   - Train batches  : 362
#   - Val batches    : 13
#   - Batch size     : 32
#   - Image size     : (224, 224)
#
#   - Train samples  : ~11584
#   - Val samples    : ~416
# CPU times: total: 328 ms
# Wall time: 331 ms

# %%
#%%time

# Prétraitement et (Data Augmentation)

# Créer un modèle d'augmentation de données plus agressif
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.3),
    layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    layers.RandomTranslation(height_factor=0.2, width_factor=0.2),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(factor=0.2),
], name="data_augmentation")

# Fonction pour appliquer le prétraitement
def normalize(x, y):
    return preprocess_input(x), y

def augment_fn(x, y):
    return data_augmentation(x, training=True), y

def prepare_dataset(ds, augment=False, shuffle=True):

    if shuffle:
        ds = ds.shuffle(1000)

    # 🔥 1. AUGMENTATION D’ABORD
    if augment:
        ds = ds.map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE)

    # 🔥 2. NORMALISATION ENSUITE
    ds = ds.map(normalize, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.cache()

    # Prefetch
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)

    return ds


# Appliquer le prétraitement
train_ds_prepared = prepare_dataset(train_ds, augment=False, shuffle=True)         # Pas d'augmentation car fait précédemment
val_ds_prepared = prepare_dataset(val_ds, augment=False, shuffle=False)

print(f"\n  - Train batches  : {len(train_ds_prepared)}")
print(f"  - Val batches    : {len(val_ds_prepared)}")
print(f"\n  - Train samples  : ~{len(train_ds_prepared) * BATCH_SIZE}")
print(f"  - Val samples    : ~{len(val_ds_prepared) * BATCH_SIZE}")
# Out:
#   - Train batches  : 362
#   - Val batches    : 13
#
#   - Train samples  : ~11584
#   - Val samples    : ~416

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Chargement du modele MobileNetV2<br>
#
# Ce modèle est choisi pour sa légèreté et donc sa rapidité d'entrainement. Il donne malgrès tout des résultats corrects dans notre cas de classification.
# </div>

# %% [markdown]
# -------------------------------
# # Modèle
# -------------------------------

# %%
# %%time

# Chargement MobileNetV2 pré-entraîné sans le classifier (include_top=False)
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,  # Exclure la couche de classification ImageNet
    weights='imagenet',  # Charger les poids pré-entraînés sur ImageNet
    pooling='avg'  # Global Average Pooling à la fin
)

# Verouillage de toutes les couches une à une pour que ça apparaisse correctement à l'affichage des couches
for i, layer in enumerate(base_model.layers):
    layer.trainable = False

    
print("✅ Modèle MobileNetV2 chargé !\n")

# Afficher la structure du modèle
print("📋 Structure du modèle MobileNetV2 :")
print(f"  - Architecture   : MobileNetV2")
print(f"  - Input shape    : (224, 224, 3)")
print(f"  - Poids          : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Nombre de couches : {len(base_model.layers)}")

# Compter les paramètres
total_params = base_model.count_params()
print(f"\n  - Nombre total de paramètres : {total_params:,}")
print(f"  - Taille en mémoire (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# ✅ Modèle MobileNetV2 chargé !
#
# 📋 Structure du modèle MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (224, 224, 3)
#   - Poids          : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Nombre de couches : 155
#
#   - Nombre total de paramètres : 2,257,984
#   - Taille en mémoire (approx.) : 8.6 MB
# CPU times: total: 500 ms
# Wall time: 450 ms

# %%
# %%time
print("🔍 Aperçu des couches de MobileNetV2\n")
print("="*80)

# Fonction helper pour obtenir l'output shape
def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

def affiche_couches(p_model):
    # Afficher les 15 premières et 15 dernières couches
    print("\n📌 Premières couches (extraction de features bas niveau) :")
    for i, layer in enumerate(p_model.layers[:15]):
        output_shape = get_output_shape(layer)
        print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

    print("\n      ...")

    print("\n📌 Dernières couches (features haut niveau) :")
    for i, layer in enumerate(p_model.layers[-15:], start=len(p_model.layers)-15):
        output_shape = get_output_shape(layer)
        print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

    print("\n" + "="*80)

#affiche_couches(base_model)

def print_layers(p_model, n=0):
    for i, layer in enumerate(p_model.layers):
        # print(prefix + layer.name)
        output_shape = get_output_shape(layer)
        if n==0:
            print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")
        else:
            print(f"  {n:3d}.  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")
        if hasattr(layer, "layers"):  # modèle imbriqué
            x = i + 1
            print_layers(layer, x)

print_layers(base_model)
# Out:
# 🔍 Aperçu des couches de MobileNetV2
#
# ================================================================================
#     1. input_layer                              | Output: (None, 224, 224, 3)            | Trainable: False
#     2. Conv1                                    | Output: (None, 112, 112, 32)           | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 112, 112, 32)           | Trainable: False
#     4. Conv1_relu                               | Output: (None, 112, 112, 32)           | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 112, 112, 32)           | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 112, 112, 32)           | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 112, 112, 32)           | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 112, 112, 16)           | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 112, 112, 16)           | Trainable: False
#    10. block_1_expand                           | Output: (None, 112, 112, 96)           | Trainable: False
#    11. block_1_expand_BN                        | Output: (None, 112, 112, 96)           | Trainable: False
#    12. block_1_expand_relu                      | Output: (None, 112, 112, 96)           | Trainable: False
#    13. block_1_pad                              | Output: (None, 113, 113, 96)           | Trainable: False
#    14. block_1_depthwise                        | Output: (None, 56, 56, 96)             | Trainable: False
#    15. block_1_depthwise_BN                     | Output: (None, 56, 56, 96)             | Trainable: False
#    16. block_1_depthwise_relu                   | Output: (None, 56, 56, 96)             | Trainable: False
#    17. block_1_project                          | Output: (None, 56, 56, 24)             | Trainable: False
#    18. block_1_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: False
#    19. block_2_expand                           | Output: (None, 56, 56, 144)            | Trainable: False
#    20. block_2_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: False
#    21. block_2_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: False
#    22. block_2_depthwise                        | Output: (None, 56, 56, 144)            | Trainable: False
#    23. block_2_depthwise_BN                     | Output: (None, 56, 56, 144)            | Trainable: False
#    24. block_2_depthwise_relu                   | Output: (None, 56, 56, 144)            | Trainable: False
#    25. block_2_project                          | Output: (None, 56, 56, 24)             | Trainable: False
#    26. block_2_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: False
#    27. block_2_add                              | Output: (None, 56, 56, 24)             | Trainable: False
#    28. block_3_expand                           | Output: (None, 56, 56, 144)            | Trainable: False
#    29. block_3_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: False
#    30. block_3_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: False
#    31. block_3_pad                              | Output: (None, 57, 57, 144)            | Trainable: False
#    32. block_3_depthwise                        | Output: (None, 28, 28, 144)            | Trainable: False
#    33. block_3_depthwise_BN                     | Output: (None, 28, 28, 144)            | Trainable: False
#    34. block_3_depthwise_relu                   | Output: (None, 28, 28, 144)            | Trainable: False
#    35. block_3_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#    36. block_3_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#    37. block_4_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#    38. block_4_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#    39. block_4_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#    40. block_4_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: False
#    41. block_4_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: False
#    42. block_4_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: False
#    43. block_4_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#    44. block_4_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#    45. block_4_add                              | Output: (None, 28, 28, 32)             | Trainable: False
#    46. block_5_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#    47. block_5_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#    48. block_5_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#    49. block_5_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: False
#    50. block_5_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: False
#    51. block_5_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: False
#    52. block_5_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#    53. block_5_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#    54. block_5_add                              | Output: (None, 28, 28, 32)             | Trainable: False
#    55. block_6_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#    56. block_6_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#    57. block_6_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#    58. block_6_pad                              | Output: (None, 29, 29, 192)            | Trainable: False
#    59. block_6_depthwise                        | Output: (None, 14, 14, 192)            | Trainable: False
#    60. block_6_depthwise_BN                     | Output: (None, 14, 14, 192)            | Trainable: False
#    61. block_6_depthwise_relu                   | Output: (None, 14, 14, 192)            | Trainable: False
#    62. block_6_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#    63. block_6_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#    64. block_7_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#    65. block_7_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#    66. block_7_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#    67. block_7_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#    68. block_7_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#    69. block_7_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#    70. block_7_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#    71. block_7_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#    72. block_7_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#    73. block_8_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#    74. block_8_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#    75. block_8_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#    76. block_8_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#    77. block_8_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#    78. block_8_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#    79. block_8_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#    80. block_8_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#    81. block_8_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#    82. block_9_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#    83. block_9_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#    84. block_9_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#    85. block_9_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#    86. block_9_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#    87. block_9_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#    88. block_9_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#    89. block_9_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#    90. block_9_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#    91. block_10_expand                          | Output: (None, 14, 14, 384)            | Trainable: False
#    92. block_10_expand_BN                       | Output: (None, 14, 14, 384)            | Trainable: False
#    93. block_10_expand_relu                     | Output: (None, 14, 14, 384)            | Trainable: False
#    94. block_10_depthwise                       | Output: (None, 14, 14, 384)            | Trainable: False
#    95. block_10_depthwise_BN                    | Output: (None, 14, 14, 384)            | Trainable: False
#    96. block_10_depthwise_relu                  | Output: (None, 14, 14, 384)            | Trainable: False
#    97. block_10_project                         | Output: (None, 14, 14, 96)             | Trainable: False
#    98. block_10_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: False
#    99. block_11_expand                          | Output: (None, 14, 14, 576)            | Trainable: False
#   100. block_11_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: False
#   101. block_11_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: False
#   102. block_11_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: False
#   103. block_11_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: False
#   104. block_11_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: False
#   105. block_11_project                         | Output: (None, 14, 14, 96)             | Trainable: False
#   106. block_11_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: False
#   107. block_11_add                             | Output: (None, 14, 14, 96)             | Trainable: False
#   108. block_12_expand                          | Output: (None, 14, 14, 576)            | Trainable: False
#   109. block_12_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: False
#   110. block_12_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: False
#   111. block_12_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: False
#   112. block_12_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: False
#   113. block_12_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: False
#   114. block_12_project                         | Output: (None, 14, 14, 96)             | Trainable: False
#   115. block_12_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: False
#   116. block_12_add                             | Output: (None, 14, 14, 96)             | Trainable: False
#   117. block_13_expand                          | Output: (None, 14, 14, 576)            | Trainable: False
#   118. block_13_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: False
#   119. block_13_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: False
#   120. block_13_pad                             | Output: (None, 15, 15, 576)            | Trainable: False
#   121. block_13_depthwise                       | Output: (None, 7, 7, 576)              | Trainable: False
#   122. block_13_depthwise_BN                    | Output: (None, 7, 7, 576)              | Trainable: False
#   123. block_13_depthwise_relu                  | Output: (None, 7, 7, 576)              | Trainable: False
#   124. block_13_project                         | Output: (None, 7, 7, 160)              | Trainable: False
#   125. block_13_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: False
#   126. block_14_expand                          | Output: (None, 7, 7, 960)              | Trainable: False
#   127. block_14_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: False
#   128. block_14_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: False
#   129. block_14_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: False
#   130. block_14_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: False
#   131. block_14_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: False
#   132. block_14_project                         | Output: (None, 7, 7, 160)              | Trainable: False
#   133. block_14_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: False
#   134. block_14_add                             | Output: (None, 7, 7, 160)              | Trainable: False
#   135. block_15_expand                          | Output: (None, 7, 7, 960)              | Trainable: False
#   136. block_15_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: False
#   137. block_15_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: False
#   138. block_15_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: False
#   139. block_15_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: False
#   140. block_15_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: False
#   141. block_15_project                         | Output: (None, 7, 7, 160)              | Trainable: False
#   142. block_15_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: False
#   143. block_15_add                             | Output: (None, 7, 7, 160)              | Trainable: False
#   144. block_16_expand                          | Output: (None, 7, 7, 960)              | Trainable: False
#   145. block_16_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: False
#   146. block_16_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 7, 7, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 7, 7, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 7, 7, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 7, 7, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 7, 7, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
# CPU times: total: 0 ns
# Wall time: 1.16 ms

# %%
# %%time
# Feature Extraction : Transfert-Learning

# Obtenir les noms de classes
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"  - Classes        : {class_names}")
print(f"  - Nombre de classes : {num_classes}")

# Geler le modèle de base
base_model.trainable = False

# Architecture OPTIMALE pour ce dataset
inputs = keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)

# Classifier avec régularisation modérée
x = layers.Dropout(0.3)(x)  # Dropout modéré
x = layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model_frozen = keras.Model(inputs, outputs, name='MobileNetV2_Frozen')

# Compiler avec LR optimal
model_frozen.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("\n✅ Modèle compilé !\n")

trainable = sum([tf.size(w).numpy() for w in model_frozen.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in model_frozen.non_trainable_weights])
print(f"  - Paramètres entraînables    : {trainable:,}")
print(f"  - Paramètres non-entraînables: {non_trainable:,}")
print(f"  - Total                      : {trainable + non_trainable:,}")

model_frozen.summary()
# Out:
#   - Classes        : ['00-normal', '01-minor', '02-moderate', '03-severe']
#   - Nombre de classes : 4
#
# ✅ Modèle compilé !
#
#   - Paramètres entraînables    : 328,964
#   - Paramètres non-entraînables: 2,257,984
#   - Total                      : 2,586,948
# Model: "MobileNetV2_Frozen"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,586,948 (9.87 MB)
#  Trainable params: 328,964 (1.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# CPU times: total: 62.5 ms
# Wall time: 72.4 ms

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Entraînement du modèle en mode gelé<br>
#
# Cette première étape va permettre d'utiliser le modèle pré-entrainé tel quel
# en ne rajoutant en fin que des couches permettant notre classification en 4 classes.
# </div>

# %% [markdown]
# --------------------
# # Entraînement du modèle frozen
# --------------------

# %%
# %%time

# Callbacks
early_stopping = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,  # Patience raisonnable
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-7,
    verbose=1
)

checkpoint = callbacks.ModelCheckpoint(
    'best_model_frozen.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=0
)

class SaveImagesCallback(tf.keras.callbacks.Callback):
    def __init__(self, dataset, output_dir="epoch_images", num_images=5):
        super().__init__()
        self.dataset = dataset
        self.output_dir = output_dir
        self.num_images = num_images

        # créer dossier principal
        os.makedirs(self.output_dir, exist_ok=True)

    def on_epoch_end(self, epoch, logs=None):
        epoch_dir = os.path.join(self.output_dir, f"epoch_{epoch+1}")
        os.makedirs(epoch_dir, exist_ok=True)

        for images, _ in self.dataset.take(1):
            for i in range(self.num_images):
                img = images[i].numpy()
                
                #print(img.min(), img.max())
                # dénormalisation MobileNetV2 (-1,1 → 0,1)
                #img = (img + 1.0) / 2.0
                img = ((img + 1.0) / 2.0 * 255).astype("uint8")
                #print(img.min(), img.max())

                # sauvegarde
                filepath = os.path.join(epoch_dir, f"img_{i}.png")
                plt.imsave(filepath, img)

        print(f"Images sauvegardées dans : {epoch_dir}")

#callback = SaveImagesCallback(train_ds_prepared)


EPOCHS_FROZEN = 50

history_frozen = model_frozen.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=EPOCHS_FROZEN,
    callbacks=[early_stopping, reduce_lr, checkpoint],
    verbose=1
)

print("\n✅ Entraînement frozen terminé !")
print(f"   Epochs effectués : {len(history_frozen.history['loss'])}")

best_val_acc = max(history_frozen.history['val_accuracy'])
best_epoch = history_frozen.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

if best_val_acc < 0.70:
    print(f"\n⚠️  Accuracy de {best_val_acc*100:.1f}% est en dessous de 70%")
    print("   Le modèle pourrait bénéficier de plus d'entraînement.")
elif best_val_acc < 0.80:
    print(f"\n✅ Bon résultat : {best_val_acc*100:.1f}%")
else:
    print(f"\n🎯 Excellent ! Accuracy de {best_val_acc*100:.1f}%")
# Out:
# Epoch 1/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 68s 162ms/step - accuracy: 0.6012 - loss: 2.4880 - top2_accuracy: 0.8400 - val_accuracy: 0.7616 - val_loss: 1.1098 - val_top2_accuracy: 0.9294 - learning_rate: 0.0010
# Epoch 2/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 58s 161ms/step - accuracy: 0.6462 - loss: 1.1492 - top2_accuracy: 0.8668 - val_accuracy: 0.7372 - val_loss: 0.8865 - val_top2_accuracy: 0.9221 - learning_rate: 0.0010
# Epoch 3/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 58s 161ms/step - accuracy: 0.6547 - loss: 1.0171 - top2_accuracy: 0.8724 - val_accuracy: 0.7713 - val_loss: 0.7468 - val_top2_accuracy: 0.9367 - learning_rate: 0.0010
# Epoch 4/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 59s 162ms/step - accuracy: 0.6638 - loss: 0.9713 - top2_accuracy: 0.8765 - val_accuracy: 0.7689 - val_loss: 0.7624 - val_top2_accuracy: 0.9294 - learning_rate: 0.0010
# Epoch 5/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 58s 160ms/step - accuracy: 0.6553 - loss: 0.9619 - top2_accuracy: 0.8750 - val_accuracy: 0.7713 - val_loss: 0.7550 - val_top2_accuracy: 0.9367 - learning_rate: 0.0010
# Epoch 6/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 58s 161ms/step - accuracy: 0.6609 - loss: 0.9527 - top2_accuracy: 0.8801 - val_accuracy: 0.7981 - val_loss: 0.7322 - val_top2_accuracy: 0.9197 - learning_rate: 0.0010
# Epoch 7/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 159ms/step - accuracy: 0.6614 - loss: 0.9509 - top2_accuracy: 0.8774 - val_accuracy: 0.7810 - val_loss: 0.7281 - val_top2_accuracy: 0.9416 - learning_rate: 0.0010
# Epoch 8/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 159ms/step - accuracy: 0.6625 - loss: 0.9415 - top2_accuracy: 0.8810 - val_accuracy: 0.7567 - val_loss: 0.7119 - val_top2_accuracy: 0.9319 - learning_rate: 0.0010
# Epoch 9/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 159ms/step - accuracy: 0.6666 - loss: 0.9420 - top2_accuracy: 0.8772 - val_accuracy: 0.7810 - val_loss: 0.7160 - val_top2_accuracy: 0.9319 - learning_rate: 0.0010
# Epoch 10/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 58s 160ms/step - accuracy: 0.6647 - loss: 0.9403 - top2_accuracy: 0.8794 - val_accuracy: 0.7713 - val_loss: 0.7234 - val_top2_accuracy: 0.9197 - learning_rate: 0.0010
# Epoch 11/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 159ms/step - accuracy: 0.6664 - loss: 0.9400 - top2_accuracy: 0.8776 - val_accuracy: 0.7713 - val_loss: 0.7089 - val_top2_accuracy: 0.9367 - learning_rate: 0.0010
# Epoch 12/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 159ms/step - accuracy: 0.6686 - loss: 0.9260 - top2_accuracy: 0.8836 - val_accuracy: 0.7713 - val_loss: 0.7277 - val_top2_accuracy: 0.9294 - learning_rate: 0.0010
# Epoch 13/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 58s 159ms/step - accuracy: 0.6630 - loss: 0.9360 - top2_accuracy: 0.8834 - val_accuracy: 0.7786 - val_loss: 0.7293 - val_top2_accuracy: 0.9294 - learning_rate: 0.0010
# Epoch 14/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 159ms/step - accuracy: 0.6653 - loss: 0.9270 - top2_accuracy: 0.8827 - val_accuracy: 0.7762 - val_loss: 0.7003 - val_top2_accuracy: 0.9392 - learning_rate: 0.0010
# Epoch 15/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 158ms/step - accuracy: 0.6688 - loss: 0.9230 - top2_accuracy: 0.8833 - val_accuracy: 0.7835 - val_loss: 0.7008 - val_top2_accuracy: 0.9367 - learning_rate: 0.0010
# Epoch 16/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 57s 158ms/step - accuracy: 0.6616 - loss: 0.9342 - top2_accuracy: 0.8815 - val_accuracy: 0.7640 - val_loss: 0.7416 - val_top2_accuracy: 0.9100 - learning_rate: 0.0010
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
# ✅ Entraînement frozen terminé !
#    Epochs effectués : 16
#    Meilleure val_accuracy : 79.81% (epoch 6)
#
# ✅ Bon résultat : 79.8%
# CPU times: total: 2h 57min 27s
# Wall time: 15min 34s

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Evaluation de cet entrainement<br>
#
# </div>

# %%
# %%time

def evaluation(p_history):
    # Epoch optimal (val_loss minimal)
    val_loss = p_history.history['val_loss']
    optimal_epoch = np.argmin(val_loss)
    optimal_val_loss = val_loss[optimal_epoch]
    print(f"Epoch optimal détecté : {optimal_epoch + 1} avec val_loss = {optimal_val_loss:.4f}")

    # Tracer loss et accuracy avec repère
    plt.figure(figsize=(14,5))

    # Loss
    plt.subplot(1,2,1)
    plt.plot(p_history.history['loss'], label='train loss')
    plt.plot(p_history.history['val_loss'], label='val loss')
    plt.axvline(optimal_epoch, color='r', linestyle='--', label=f'Optimal epoch ({optimal_epoch + 1})')
    plt.scatter(optimal_epoch, optimal_val_loss, color='red', s=100, zorder=5)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss par epoch')
    plt.legend()

    # Accuracy
    plt.subplot(1,2,2)
    plt.plot(p_history.history['accuracy'], label='train acc')
    plt.plot(p_history.history['val_accuracy'], label='val acc')
    plt.axvline(optimal_epoch, color='r', linestyle='--', label=f'Optimal epoch ({optimal_epoch + 1})')
    plt.scatter(optimal_epoch, p_history.history['val_accuracy'][optimal_epoch], color='red', s=100, zorder=5)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy par epoch')
    plt.legend()

    plt.show()

evaluation(history_frozen)
# Out:
# Epoch optimal détecté : 14 avec val_loss = 0.7003
# CPU times: total: 156 ms
# Wall time: 224 ms

# %%
# %%time
# Matrice de confusion

def matrice_confusion(p_model, p_dataset):
    y_val = np.concatenate([y for x, y in p_dataset], axis=0)
    y_val = np.argmax(y_val, axis=1)
    y_pred_probs = p_model.predict(p_dataset)
    y_pred_classes = np.argmax(y_pred_probs, axis=1)

    cm = confusion_matrix(y_val, y_pred_classes)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

    # Normalisation par ligne (chaque ligne = 100%)
    cm_norm = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    # Conversion en pourcentage
    cm_percent = cm_norm * 100

    # Affichage
    plt.figure(figsize=(8,6))
    sns.heatmap(cm_percent, 
                annot=True, 
                fmt=".1f", 
                cmap="Blues")

    plt.xlabel('Prédictions')
    plt.ylabel('Vraies classes')
    plt.title('Matrice de confusion (%)')

    plt.show()

    # Rapport de classification
    print("\n📄 Rapport de classification détaillé :\n")
    print(classification_report(y_val, y_pred_classes, target_names=class_names, digits=3))


matrice_confusion(model_frozen, val_ds_prepared)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step
# 📄 Rapport de classification détaillé :
#
#               precision    recall  f1-score   support
#
#    00-normal      0.897     0.957     0.926       163
#     01-minor      0.737     0.854     0.791        82
#  02-moderate      0.615     0.427     0.504        75
#    03-severe      0.778     0.769     0.773        91
#
#     accuracy                          0.798       411
#    macro avg      0.757     0.752     0.749       411
# weighted avg      0.787     0.798     0.788       411
#
# CPU times: total: 23.9 s
# Wall time: 3.19 s

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Fine-Tuning<br>
#
# Dans cette étape on va dégeler une partie des couches du modèle et l'entrainer en gardant un coefficiant de correction des poids du modèle initial très bas pour ne pas perturber le pré-entrainement initial mais en applicant quand même de petites corrections correspondant à nos données propres.
# </div>

# %% [markdown]
# --------------------------
# # Fine-Tuning
# --------------------------

# %%
# %%time

# Évaluation AVANT fine-tuning
print("📈 Performance AVANT fine-tuning :")
results_before = model_frozen.evaluate(val_ds_prepared, verbose=0)
print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")

# clone du modèle avec ses poids
# model_finetuned = clone_model(model_frozen)
# model_finetuned.set_weights(model_frozen.get_weights())

# Dégeler le base_model
base_model.trainable = True

# Geler seulement les 100 premières couches
fine_tune_at = 100

for i, layer in enumerate(base_model.layers):
    if i < fine_tune_at:
        layer.trainable = False
    else:
        layer.trainable = True

print(f"📊 Configuration du dégel :")
print(f"  - Couches frozen  : {fine_tune_at}")
print(f"  - Couches unfrozen: {len(base_model.layers) - fine_tune_at}")

# Compter les paramètres
trainable_count = sum([tf.size(w).numpy() for w in model_frozen.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in model_frozen.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Paramètres entraînables : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Paramètres frozen       : {non_trainable_count:,}\n")

# Recompiler avec un LR très faible
FINE_TUNE_LR = 1e-5  # LR très faible

model_frozen.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Le modèle fine-tuned est le modèle frozen modifié
model_finetuned = model_frozen

print_layers(model_finetuned)

print(f"✅ Modèle recompilé avec LR = {FINE_TUNE_LR}")
print("\n💡 Le modèle va continuer depuis les poids déjà appris.")

# Vérification immédiate
print("\n🔍 Vérification immédiate :")
results_after_compile = model_finetuned.evaluate(val_ds_prepared, verbose=0)
print(f"  - Accuracy : {results_after_compile[1]*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Parfait ! Les poids sont préservés ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Les performances ont changé après recompilation")
# Out:
# 📈 Performance AVANT fine-tuning :
#   - Accuracy : 79.81%
#   - Loss     : 0.7322
#
# 📊 Configuration du dégel :
#   - Couches frozen  : 100
#   - Couches unfrozen: 55
#   - Paramètres entraînables : 2,190,404 (84.7%)
#   - Paramètres frozen       : 396,544
#
#     1. input_layer_1                            | Output: (None, 224, 224, 3)            | Trainable: True
#     2. mobilenetv2_1.00_224                     | Output: (None, 1280)                   | Trainable: True
#     2.    1. input_layer                              | Output: (None, 224, 224, 3)            | Trainable: False
#     2.    2. Conv1                                    | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    3. bn_Conv1                                 | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    4. Conv1_relu                               | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    5. expanded_conv_depthwise                  | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    6. expanded_conv_depthwise_BN               | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    7. expanded_conv_depthwise_relu             | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    8. expanded_conv_project                    | Output: (None, 112, 112, 16)           | Trainable: False
#     2.    9. expanded_conv_project_BN                 | Output: (None, 112, 112, 16)           | Trainable: False
#     2.   10. block_1_expand                           | Output: (None, 112, 112, 96)           | Trainable: False
#     2.   11. block_1_expand_BN                        | Output: (None, 112, 112, 96)           | Trainable: False
#     2.   12. block_1_expand_relu                      | Output: (None, 112, 112, 96)           | Trainable: False
#     2.   13. block_1_pad                              | Output: (None, 113, 113, 96)           | Trainable: False
#     2.   14. block_1_depthwise                        | Output: (None, 56, 56, 96)             | Trainable: False
#     2.   15. block_1_depthwise_BN                     | Output: (None, 56, 56, 96)             | Trainable: False
#     2.   16. block_1_depthwise_relu                   | Output: (None, 56, 56, 96)             | Trainable: False
#     2.   17. block_1_project                          | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   18. block_1_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   19. block_2_expand                           | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   20. block_2_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   21. block_2_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   22. block_2_depthwise                        | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   23. block_2_depthwise_BN                     | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   24. block_2_depthwise_relu                   | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   25. block_2_project                          | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   26. block_2_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   27. block_2_add                              | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   28. block_3_expand                           | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   29. block_3_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   30. block_3_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   31. block_3_pad                              | Output: (None, 57, 57, 144)            | Trainable: False
#     2.   32. block_3_depthwise                        | Output: (None, 28, 28, 144)            | Trainable: False
#     2.   33. block_3_depthwise_BN                     | Output: (None, 28, 28, 144)            | Trainable: False
#     2.   34. block_3_depthwise_relu                   | Output: (None, 28, 28, 144)            | Trainable: False
#     2.   35. block_3_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   36. block_3_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   37. block_4_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   38. block_4_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   39. block_4_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   40. block_4_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   41. block_4_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   42. block_4_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   43. block_4_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   44. block_4_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   45. block_4_add                              | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   46. block_5_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   47. block_5_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   48. block_5_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   49. block_5_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   50. block_5_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   51. block_5_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   52. block_5_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   53. block_5_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   54. block_5_add                              | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   55. block_6_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   56. block_6_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   57. block_6_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   58. block_6_pad                              | Output: (None, 29, 29, 192)            | Trainable: False
#     2.   59. block_6_depthwise                        | Output: (None, 14, 14, 192)            | Trainable: False
#     2.   60. block_6_depthwise_BN                     | Output: (None, 14, 14, 192)            | Trainable: False
#     2.   61. block_6_depthwise_relu                   | Output: (None, 14, 14, 192)            | Trainable: False
#     2.   62. block_6_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   63. block_6_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   64. block_7_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   65. block_7_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   66. block_7_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   67. block_7_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   68. block_7_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   69. block_7_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   70. block_7_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   71. block_7_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   72. block_7_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   73. block_8_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   74. block_8_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   75. block_8_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   76. block_8_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   77. block_8_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   78. block_8_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   79. block_8_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   80. block_8_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   81. block_8_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   82. block_9_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   83. block_9_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   84. block_9_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   85. block_9_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   86. block_9_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   87. block_9_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   88. block_9_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   89. block_9_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   90. block_9_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   91. block_10_expand                          | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   92. block_10_expand_BN                       | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   93. block_10_expand_relu                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   94. block_10_depthwise                       | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   95. block_10_depthwise_BN                    | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   96. block_10_depthwise_relu                  | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   97. block_10_project                         | Output: (None, 14, 14, 96)             | Trainable: False
#     2.   98. block_10_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: False
#     2.   99. block_11_expand                          | Output: (None, 14, 14, 576)            | Trainable: False
#     2.  100. block_11_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: False
#     2.  101. block_11_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  102. block_11_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  103. block_11_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  104. block_11_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  105. block_11_project                         | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  106. block_11_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  107. block_11_add                             | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  108. block_12_expand                          | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  109. block_12_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  110. block_12_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  111. block_12_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  112. block_12_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  113. block_12_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  114. block_12_project                         | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  115. block_12_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  116. block_12_add                             | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  117. block_13_expand                          | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  118. block_13_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  119. block_13_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  120. block_13_pad                             | Output: (None, 15, 15, 576)            | Trainable: True
#     2.  121. block_13_depthwise                       | Output: (None, 7, 7, 576)              | Trainable: True
#     2.  122. block_13_depthwise_BN                    | Output: (None, 7, 7, 576)              | Trainable: True
#     2.  123. block_13_depthwise_relu                  | Output: (None, 7, 7, 576)              | Trainable: True
#     2.  124. block_13_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  125. block_13_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  126. block_14_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  127. block_14_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  128. block_14_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  129. block_14_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  130. block_14_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  131. block_14_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  132. block_14_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  133. block_14_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  134. block_14_add                             | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  135. block_15_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  136. block_15_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  137. block_15_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  138. block_15_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  139. block_15_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  140. block_15_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  141. block_15_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  142. block_15_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  143. block_15_add                             | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  144. block_16_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  145. block_16_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  146. block_16_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  147. block_16_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  148. block_16_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  149. block_16_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  150. block_16_project                         | Output: (None, 7, 7, 320)              | Trainable: True
#     2.  151. block_16_project_BN                      | Output: (None, 7, 7, 320)              | Trainable: True
#     2.  152. Conv_1                                   | Output: (None, 7, 7, 1280)             | Trainable: True
#     2.  153. Conv_1_bn                                | Output: (None, 7, 7, 1280)             | Trainable: True
#     2.  154. out_relu                                 | Output: (None, 7, 7, 1280)             | Trainable: True
#     2.  155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 4)                      | Trainable: True
# ✅ Modèle recompilé avec LR = 1e-05
#
# 💡 Le modèle va continuer depuis les poids déjà appris.
#
# 🔍 Vérification immédiate :
#   - Accuracy : 79.81%
#   - Loss     : 0.7322
#
#   ✅ Parfait ! Les poids sont préservés (79.8%)
# CPU times: total: 45.4 s
# Wall time: 4.98 s

# %% [markdown]
# -------------------------------
# # Entraînement du modèle fine-tuned
# -------------------------------

# %%
# %%time

print("🚀 Fine-tuning du modèle...\n")
print("⚠️  Le modèle continue depuis les poids frozen déjà entraînés\n")

# Callbacks pour fine-tuning
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=20,  # Beaucoup de patience
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=10,
    min_lr=1e-8,
    verbose=1
)

checkpoint_ft = callbacks.ModelCheckpoint(
    'best_model_finetuned.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=0
)

# Entraînement
EPOCHS_FINETUNE = 50

print(f"Entraînement pour {EPOCHS_FINETUNE} epochs maximum...\n")

history_finetuned = model_finetuned.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=EPOCHS_FINETUNE,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=1
)

print("\n✅ Fine-tuning terminé !")
print(f"   Nombre d'epochs effectués : {len(history_finetuned.history['loss'])}")

# Meilleures performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
frozen_best = max(history_frozen.history['val_accuracy'])
improvement = (best_val_acc - frozen_best) * 100
print(f"\n📊 Amélioration vs Frozen : {improvement:+.2f} points de pourcentage")
print(f"   - Frozen    : {frozen_best*100:.2f}%")
print(f"   - Fine-tuned: {best_val_acc*100:.2f}%")
# Out:
# 🚀 Fine-tuning du modèle...
#
# ⚠️  Le modèle continue depuis les poids frozen déjà entraînés
#
# Entraînement pour 50 epochs maximum...
#
# Epoch 1/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 94s 243ms/step - accuracy: 0.6385 - loss: 0.9834 - top2_accuracy: 0.8712 - val_accuracy: 0.7324 - val_loss: 0.8007 - val_top2_accuracy: 0.8881 - learning_rate: 1.0000e-05
# Epoch 2/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 245ms/step - accuracy: 0.7077 - loss: 0.8259 - top2_accuracy: 0.9152 - val_accuracy: 0.7737 - val_loss: 0.7196 - val_top2_accuracy: 0.9173 - learning_rate: 1.0000e-05
# Epoch 3/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 245ms/step - accuracy: 0.7499 - loss: 0.7367 - top2_accuracy: 0.9382 - val_accuracy: 0.7835 - val_loss: 0.6452 - val_top2_accuracy: 0.9440 - learning_rate: 1.0000e-05
# Epoch 4/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.7825 - loss: 0.6725 - top2_accuracy: 0.9548 - val_accuracy: 0.8127 - val_loss: 0.6025 - val_top2_accuracy: 0.9586 - learning_rate: 1.0000e-05
# Epoch 5/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.8069 - loss: 0.6089 - top2_accuracy: 0.9663 - val_accuracy: 0.8175 - val_loss: 0.5645 - val_top2_accuracy: 0.9635 - learning_rate: 1.0000e-05
# Epoch 6/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.8328 - loss: 0.5541 - top2_accuracy: 0.9758 - val_accuracy: 0.8127 - val_loss: 0.5523 - val_top2_accuracy: 0.9684 - learning_rate: 1.0000e-05
# Epoch 7/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.8595 - loss: 0.5015 - top2_accuracy: 0.9828 - val_accuracy: 0.8224 - val_loss: 0.5309 - val_top2_accuracy: 0.9732 - learning_rate: 1.0000e-05
# Epoch 8/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.8804 - loss: 0.4541 - top2_accuracy: 0.9902 - val_accuracy: 0.8248 - val_loss: 0.5259 - val_top2_accuracy: 0.9757 - learning_rate: 1.0000e-05
# Epoch 9/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.9052 - loss: 0.4066 - top2_accuracy: 0.9921 - val_accuracy: 0.8345 - val_loss: 0.5314 - val_top2_accuracy: 0.9757 - learning_rate: 1.0000e-05
# Epoch 10/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 247ms/step - accuracy: 0.9251 - loss: 0.3657 - top2_accuracy: 0.9952 - val_accuracy: 0.8370 - val_loss: 0.5355 - val_top2_accuracy: 0.9708 - learning_rate: 1.0000e-05
# Epoch 11/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.9410 - loss: 0.3249 - top2_accuracy: 0.9976 - val_accuracy: 0.8370 - val_loss: 0.5388 - val_top2_accuracy: 0.9708 - learning_rate: 1.0000e-05
# Epoch 12/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.9549 - loss: 0.2899 - top2_accuracy: 0.9987 - val_accuracy: 0.8321 - val_loss: 0.5432 - val_top2_accuracy: 0.9708 - learning_rate: 1.0000e-05
# Epoch 13/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.9698 - loss: 0.2546 - top2_accuracy: 0.9990 - val_accuracy: 0.8297 - val_loss: 0.5505 - val_top2_accuracy: 0.9708 - learning_rate: 1.0000e-05
# Epoch 14/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.9771 - loss: 0.2286 - top2_accuracy: 0.9993 - val_accuracy: 0.8248 - val_loss: 0.5743 - val_top2_accuracy: 0.9684 - learning_rate: 1.0000e-05
# Epoch 15/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 89s 246ms/step - accuracy: 0.9849 - loss: 0.2028 - top2_accuracy: 0.9997 - val_accuracy: 0.8151 - val_loss: 0.5794 - val_top2_accuracy: 0.9684 - learning_rate: 1.0000e-05
# Epoch 16/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9911 - loss: 0.1814 - top2_accuracy: 0.9997 - val_accuracy: 0.8127 - val_loss: 0.6002 - val_top2_accuracy: 0.9659 - learning_rate: 1.0000e-05
# Epoch 17/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 247ms/step - accuracy: 0.9941 - loss: 0.1654 - top2_accuracy: 0.9999 - val_accuracy: 0.8151 - val_loss: 0.6274 - val_top2_accuracy: 0.9659 - learning_rate: 1.0000e-05
# Epoch 18/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9953 - loss: 0.1534 - top2_accuracy: 0.9999
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 250ms/step - accuracy: 0.9961 - loss: 0.1500 - top2_accuracy: 0.9999 - val_accuracy: 0.8078 - val_loss: 0.6466 - val_top2_accuracy: 0.9659 - learning_rate: 1.0000e-05
# Epoch 19/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9976 - loss: 0.1398 - top2_accuracy: 0.9999 - val_accuracy: 0.8102 - val_loss: 0.6390 - val_top2_accuracy: 0.9684 - learning_rate: 5.0000e-06
# Epoch 20/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 249ms/step - accuracy: 0.9981 - loss: 0.1321 - top2_accuracy: 0.9999 - val_accuracy: 0.8102 - val_loss: 0.6409 - val_top2_accuracy: 0.9684 - learning_rate: 5.0000e-06
# Epoch 21/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 249ms/step - accuracy: 0.9978 - loss: 0.1277 - top2_accuracy: 0.9999 - val_accuracy: 0.8127 - val_loss: 0.6603 - val_top2_accuracy: 0.9684 - learning_rate: 5.0000e-06
# Epoch 22/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9987 - loss: 0.1212 - top2_accuracy: 1.0000 - val_accuracy: 0.8102 - val_loss: 0.6690 - val_top2_accuracy: 0.9708 - learning_rate: 5.0000e-06
# Epoch 23/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9990 - loss: 0.1168 - top2_accuracy: 1.0000 - val_accuracy: 0.8102 - val_loss: 0.6760 - val_top2_accuracy: 0.9708 - learning_rate: 5.0000e-06
# Epoch 24/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 249ms/step - accuracy: 0.9992 - loss: 0.1107 - top2_accuracy: 1.0000 - val_accuracy: 0.8127 - val_loss: 0.6851 - val_top2_accuracy: 0.9708 - learning_rate: 5.0000e-06
# Epoch 25/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9993 - loss: 0.1058 - top2_accuracy: 1.0000 - val_accuracy: 0.8102 - val_loss: 0.6964 - val_top2_accuracy: 0.9684 - learning_rate: 5.0000e-06
# Epoch 26/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9994 - loss: 0.1005 - top2_accuracy: 1.0000 - val_accuracy: 0.8078 - val_loss: 0.7020 - val_top2_accuracy: 0.9708 - learning_rate: 5.0000e-06
# Epoch 27/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 249ms/step - accuracy: 0.9997 - loss: 0.0952 - top2_accuracy: 1.0000 - val_accuracy: 0.8078 - val_loss: 0.7175 - val_top2_accuracy: 0.9684 - learning_rate: 5.0000e-06
# Epoch 28/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9997 - loss: 0.0918 - top2_accuracy: 1.0000
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 249ms/step - accuracy: 0.9997 - loss: 0.0908 - top2_accuracy: 1.0000 - val_accuracy: 0.8102 - val_loss: 0.7134 - val_top2_accuracy: 0.9659 - learning_rate: 5.0000e-06
# Epoch 29/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9997 - loss: 0.0871 - top2_accuracy: 1.0000 - val_accuracy: 0.8102 - val_loss: 0.7172 - val_top2_accuracy: 0.9684 - learning_rate: 2.5000e-06
# Epoch 30/50
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.9997 - loss: 0.0840 - top2_accuracy: 1.0000 - val_accuracy: 0.8102 - val_loss: 0.7196 - val_top2_accuracy: 0.9684 - learning_rate: 2.5000e-06
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
# ✅ Fine-tuning terminé !
#    Nombre d'epochs effectués : 30
#    Meilleure val_accuracy : 83.70% (epoch 10)
#
# 📊 Amélioration vs Frozen : +3.89 points de pourcentage
#    - Frozen    : 79.81%
#    - Fine-tuned: 83.70%
# CPU times: total: 8h 41min 12s
# Wall time: 44min 50s

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Evaluation du modèle entrainé en Fine-Tuning<br>
#
# </div>

# %%
# %%time

evaluation(history_finetuned)
# Out:
# Epoch optimal détecté : 8 avec val_loss = 0.5259
# CPU times: total: 141 ms
# Wall time: 130 ms

# %%
# %%time

matrice_confusion(model_finetuned, val_ds_prepared)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step
# 📄 Rapport de classification détaillé :
#
#               precision    recall  f1-score   support
#
#    00-normal      0.958     0.988     0.973       163
#     01-minor      0.810     0.829     0.819        82
#  02-moderate      0.582     0.613     0.597        75
#    03-severe      0.863     0.758     0.807        91
#
#     accuracy                          0.837       411
#    macro avg      0.803     0.797     0.799       411
# weighted avg      0.839     0.837     0.837       411
#
# CPU times: total: 23.7 s
# Wall time: 3.23 s

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Sauvegarde de cette version du modèle<br>
#
# </div>

# %%
# %%time

# Sauvegarde du modèle

# Sauvegarder au format Keras (.keras)
model_path = 'mobilenetv2_test1_finetuned.keras'
model_finetuned.save(model_path)

with open("mobilenetv2_test1_finetuned_class_names.json", "w") as f:
    json.dump(class_names, f)

print(f"\n✅ Modèle sauvegardé : {model_path}")
print(f"   Taille du fichier : {os.path.getsize(model_path) / (1024**2):.1f} MB")

# Sauvegarder aussi au format h5 (legacy)
model_h5_path = 'mobilenetv2_test1_finetuned.h5'
model_finetuned.save(model_h5_path)
print(f"\n✅ Modèle également sauvegardé en .h5 : {model_h5_path}")


# Pour recharger le modèle
# loaded_model = keras.models.load_model(model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Modèle sauvegardé : mobilenetv2_test1_finetuned.keras
#    Taille du fichier : 27.2 MB
#
# ✅ Modèle également sauvegardé en .h5 : mobilenetv2_test1_finetuned.h5
# CPU times: total: 375 ms
# Wall time: 394 ms

# %% [markdown]
# <div style="background-color:#FFECB3; color:black; padding:10px; border-radius:5px;">
#
# Test de cette version du modèle<br>
#
# </div>

# %% [markdown]
# ---------------------------------------
# # Test
# ---------------------------------------

# %%
# %%time

# Fonction de prédiction

def predict_image(model, image_path, class_names):
    
    # Charger et prétraiter l'image
    img = load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Ajouter dimension batch
    img_array = preprocess_input(img_array)  # Normalisation MobileNetV2
    
    # Prédire
    predictions = model.predict(img_array, verbose=0)
    predicted_class_idx = np.argmax(predictions[0])
    confidence = predictions[0][predicted_class_idx]
    
    # Top 3 prédictions
    top3_idx = np.argsort(predictions[0])[-3:][::-1]
    
    return {
        'predicted_class': class_names[predicted_class_idx],
        'confidence': confidence,
        'all_probabilities': predictions[0],
        'top3': [(class_names[i], predictions[0][i]) for i in top3_idx]
    }

print("✅ Fonction de prédiction créée !")
# Out:
# ✅ Fonction de prédiction créée !
# CPU times: total: 0 ns
# Wall time: 1.01 ms

# %%
# %%time

model_path = 'mobilenetv2_test1_finetuned.keras'
loaded_model = keras.models.load_model(model_path)
class_names = ["00-normal", "01-minor", "02-moderate", "03-severe"]

# Visualisation des probabilités pour une image

from PIL import Image

# Prendre une image spécifique
sample_image_path = "C:/Users/huber_otpq54a/OneDrive/Documents/Formation/IA/Developpement/Projets/Deep_Learning/Test/accident-de-voiture.webp"

im = Image.open(sample_image_path).convert("RGB")
sample_image_path = sample_image_path + ".jpg"
im.save(sample_image_path, "JPEG")

result = predict_image(loaded_model, sample_image_path, class_names)

# Visualiser
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Image
img = plt.imread(sample_image_path)
axes[0].imshow(img)
axes[0].axis('off')
axes[0].set_title(f"Image : {str(Path(sample_image_path).name)}", fontsize=14, fontweight='bold')

# Probabilités
probs = result['all_probabilities'] * 100
colors = ['#2ecc71' if i == np.argmax(probs) else '#3498db' for i in range(len(probs))]

bars = axes[1].barh(class_names, probs, color=colors, edgecolor='black', linewidth=2)
axes[1].set_xlabel('Probabilité (%)', fontsize=13, fontweight='bold')
axes[1].set_title('Distribution des Probabilités', fontsize=14, fontweight='bold')
axes[1].grid(alpha=0.3, axis='x')

# Ajouter les valeurs
for bar, prob in zip(bars, probs):
    width = bar.get_width()
    axes[1].text(width + 1, bar.get_y() + bar.get_height()/2.,
                f'{prob:.1f}%',
                ha='left', va='center', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

print(f"\n🔍 Analyse de la prédiction :")
print(f"  - Classe prédite : {result['predicted_class']}")
print(f"  - Confiance      : {result['confidence']*100:.2f}%")
print(f"\n  - Top 3 prédictions :")
for i, (cls, prob) in enumerate(result['top3'], 1):
    print(f"    {i}. {cls:15s} : {prob*100:.2f}%")

end_time = time.time()
execution_time = end_time - start_time

# Conversion en minutes/secondes pour plus de lisibilité
minutes = int(execution_time // 60)
secondes = int(execution_time % 60)

print(f"\nTemps d'exécution global : {minutes} min {secondes} s\n")
# Out:
# 🔍 Analyse de la prédiction :
#   - Classe prédite : 02-moderate
#   - Confiance      : 55.16%
#
#   - Top 3 prédictions :
#     1. 02-moderate     : 55.16%
#     2. 03-severe       : 42.26%
#     3. 01-minor        : 2.40%
#
# Temps d'exécution global : 60 min 56 s
#
# CPU times: total: 1.75 s
# Wall time: 1.61 s
